# %% [markdown]
# <a href="https://colab.research.google.com/github/DevMazaro/eBayPricePrediction/blob/main/eBay_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **eBay Laptop Sale Price Prediction**
#
# ##**Overview**
# In the reverse logistics process, accurately predicting the potential resale value of a returned item is the critical first step in maximizing value recovery. This project develops a robust price prediction model for used laptops by leveraging a historical dataset of eBay sales from Kaggle.
#
# After extensive data cleaning and feature engineering—especially standardizing the condition field—we will train and evaluate two distinct modeling approaches. We will compare a simple Linear Regression model as a baseline against a Multi-Layer Perceptron (MLP) Neural Network to capture more complex, non-linear relationships between a laptop's features and its final sale price.
#
# The resulting price predictor is designed to be a key component in a larger decision engine, providing the crucial 'resale value' input needed to determine the most profitable disposition path for a returned laptop: resell as-is, refurbish and sell, liquidate, or recycle.

# %%
#Importing libraries to be used in the project

#Colab drive is used only during development
#from google.colab import drive

#Data manipulation and analysis
import pandas as pd
import numpy as np

# %%
#Read raw data file
#Reading from mounted google colab drive during development


df = pd.read_csv('/content/EbayPcLaptopsAndNetbooksRaw.csv')

#TODO: Read data file from github

#Data exploration and analysis
#Basic Dataset info and sample data
print("\n---Data Exploration and analysis\n")
print(f"Dataset shape:{df.shape}")
print(f"Dataset columns:\n {df.columns}")
print("First 10 rows:\n")
with pd.option_context('display.max_columns', None):
  print(df.head(10))

#Check for missing values
print(f"\nMissing Values:\n{df.isnull().sum()}")

#Statistical summary of data
print(f"\nStatistical Summary:\n{df.describe}")
# Out:
# ---Data Exploration and analysis
#
# Dataset shape:(6620, 23)
# Dataset columns:
#  Index(['Brand', 'Price', 'Rating', 'Ratings Count', 'Condition', 'Seller Note',
#        'Processor', 'Screen Size', 'Manufacturer Color', 'Color', 'Ram Size',
#        'SSD Capacity', 'GPU', 'Processor Speed', 'Type', 'Release Year',
#        'Maximum Resolution', 'Model', 'OS', 'Features', 'Hard Drive Capacity',
#        'Country Region Of Manufacture', 'Storage Type'],
#       dtype='object')
# First 10 rows:
#
#    Brand               Price              Rating  Ratings Count  \
# 0  CHUWI            $303.68                  NaN            NaN
# 1   Dell  $399.99 to $634.99                 NaN            NaN
# 2   Dell            $175.00                  NaN            NaN
# 3     HP             $84.99                  NaN            NaN
# 4   Dell            $101.22                  NaN            NaN
# 5   Acer             $49.99   4.5 out of 5 stars          193.0
# 6     HP             $39.59   4.5 out of 5 stars           23.0
# 7   Acer             $34.99     5 out of 5 stars           20.0
# 8   Dell            $279.99                  NaN            NaN
# 9     HP            $125.00     5 out of 5 stars            5.0
#
#                                            Condition  \
# 0  New: A brand-new, unused, unopened, undamaged ...
# 1  Very Good - RefurbishedThe item shows minimal ...
# 2  UsedAn item that has been used previously. The...
# 3  Good - RefurbishedThe item shows moderate wear...
# 4  Good - RefurbishedThe item shows moderate wear...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  Excellent - Refurbished: The item is in like-n...
# 9                                                NaN
#
#                                          Seller Note                Processor  \
# 0                                                NaN                Quad Core
# 1  “AAA PCs is a Microsoft Authorized Refurbisher...   Intel Core i7 8th Gen.
# 2  “Well kept, fully functional, includes battery...      Intel Core i5-6300U
# 3  “1-Year Allstate warranty. The original HP cha...          Intel Celeron N
# 4  “Laptops is tested & fully working with some s...   Intel Core i5 6th Gen.
# 5                                                NaN            Intel Celeron
# 6                                                NaN            Intel Celeron
# 7                                                NaN  Intel Celeron Dual-Core
# 8                                                NaN                   i7 7th
# 9                                                NaN  Intel Core i3 10th Gen.
#
#      Screen Size Manufacturer Color               Color Ram Size  \
# 0          14 in                NaN                Gray     8 GB
# 1          14 in                NaN               Black      NaN
# 2          14 in                NaN               Black    16 GB
# 3        11.6 in                NaN               Black     4 GB
# 4  Minimum 12.5"                NaN                 NaN     8 GB
# 5        11.6 in              Black               Black     4 GB
# 6        11.6 in                NaN               Black     4 GB
# 7      11.6 inin                NaN  Gray, Granite Gray      2GB
# 8          14 in                NaN               Black    16 GB
# 9          14 in     Mineral Silver              Silver     8 GB
#
#                             SSD Capacity                           GPU  \
# 0  1 Used,  1 support Max 1TB M.2 Extend  Intel Iris Plus Graphics 655
# 1                                    NaN        Intel UHD Graphics 620
# 2                                 500 GB             Intel HD Graphics
# 3                                    NaN         Intel HD Graphics 500
# 4                                 256 GB                    Integrated
# 5                                  16 GB                           NaN
# 6                                   16GB                           NaN
# 7                                    NaN                           NaN
# 8                                 500 GB                           NaN
# 9                                  64 GB            Intel UHD Graphics
#
#                       Processor Speed             Type         Release Year  \
# 0                  Max up to 3.80 GHz  Notebook/Laptop                 2021
# 1  4.20 GHz (1.90 GHz Base Frequency)  Notebook/Laptop  Refurbished in 2023
# 2                            2.40 GHz  Notebook/Laptop                 2019
# 3                            2.40 GHz  Notebook/Laptop                  NaN
# 4                    Minimum 1.40 GHz  Notebook/Laptop                 2015
# 5                            1.60 GHz           Laptop                 2017
# 6                            1.60 GHz  Notebook/Laptop                 2017
# 7                       1.00 GHz.4ghz          Netbook                  NaN
# 8                            2.80 GHz  Notebook/Laptop                  NaN
# 9                            2.10 GHz  Notebook/Laptop                 2020
#
#   Maximum Resolution                  Model               OS  \
# 0        2160 x 1440             CoreBook X  Windows 11 Home
# 1        1920 x 1080     Dell Latitude 7490   Windows 11 Pro
# 2        1920 x 1080    Dell Latitude E5470   Windows 10 Pro
# 3         1366 x 768    HP Chromebook 11 G6        Chrome OS
# 4         1366 x 768         Various Models       Windows 10
# 5         1366 x 768  Chromebook C738T-C44Z        Chrome OS
# 6                NaN    HP Chromebook 11 G5        Chrome OS
# 7                NaN   Chromebook C720-2848        Chrome OS
# 8        1920 x 1080     Dell Latitude 7480       win 11 pro
# 9        1920 x 1080   Samsung Chromebook 3        Chrome OS
#
#                                             Features Hard Drive Capacity  \
# 0  Backlit Keyboard,  Built-in Microphone,  Built...          512 GB SSD
# 1  Backlit Keyboard, Bluetooth, Built-in Micropho...                2 TB
# 2  10/100 LAN Card, Backlit Keyboard, Bluetooth, ...              500 GB
# 3  Bluetooth, Built-in Microphone, Built-in Webca...               16 GB
# 4  10/100 LAN Card, Built-in Microphone, Built-in...              NO HDD
# 5                             Touchscreen, Bluetooth                 NaN
# 6                         Bluetooth, Built-in Webcam               16 GB
# 7                                                NaN                16GB
# 8                                              Wi-Fi              512 GB
# 9  Touchscreen, Bluetooth, Built-in Webcam, Wi-Fi...                 NaN
#
#   Country Region Of Manufacture             Storage Type
# 0                         China  SSD (Solid State Drive)
# 1                           NaN  SSD (Solid State Drive)
# 2                         China  SSD (Solid State Drive)
# 3                           NaN                     eMMC
# 4                           NaN  SSD (Solid State Drive)
# 5                           NaN  SSD (Solid State Drive)
# 6                           NaN  SSD (Solid State Drive)
# 7                           NaN                      NaN
# 8                           NaN  SSD (Solid State Drive)
# 9                           NaN                     eMMC
#
# Missing Values:
# Brand                            2596
# Price                               0
# Rating                           6334
# Ratings Count                    6334
# Condition                         616
# Seller Note                      5178
# Processor                        2783
# Screen Size                      2730
# Manufacturer Color               6435
# Color                            4471
# Ram Size                         4508
# SSD Capacity                     3840
# GPU                              3532
# Processor Speed                  3951
# Type                             3331
# Release Year                     5833
# Maximum Resolution               4140
# Model                            3472
# OS                               3580
# Features                         4115
# Hard Drive Capacity              4288
# Country Region Of Manufacture    6417
# Storage Type                     4232
# dtype: int64
#
# Statistical Summary:
# <bound method NDFrame.describe of        Brand               Price Rating  Ratings Count  \
# 0      CHUWI            $303.68     NaN            NaN
# 1       Dell  $399.99 to $634.99    NaN            NaN
# 2       Dell            $175.00     NaN            NaN
# 3         HP             $84.99     NaN            NaN
# 4       Dell            $101.22     NaN            NaN
# ...      ...                 ...    ...            ...
# 6615     NaN            $108.06     NaN            NaN
# 6616     NaN          $2,108.99     NaN            NaN
# 6617     NaN            $105.86     NaN            NaN
# 6618  Lenovo            $567.74     NaN            NaN
# 6619     NaN             $89.28     NaN            NaN
#
#                                               Condition  \
# 0     New: A brand-new, unused, unopened, undamaged ...
# 1     Very Good - RefurbishedThe item shows minimal ...
# 2     UsedAn item that has been used previously. The...
# 3     Good - RefurbishedThe item shows moderate wear...
# 4     Good - RefurbishedThe item shows moderate wear...
# ...                                                 ...
# 6615  New: A brand-new, unused, unopened, undamaged ...
# 6616  Seller refurbished: The item has been restored...
# 6617  New: A brand-new, unused, unopened, undamaged ...
# 6618                                                NaN
# 6619  New: A brand-new, unused, unopened, undamaged ...
#
#                                             Seller Note  \
# 0                                                   NaN
# 1     “AAA PCs is a Microsoft Authorized Refurbisher...
# 2     “Well kept, fully functional, includes battery...
# 3     “1-Year Allstate warranty. The original HP cha...
# 4     “Laptops is tested & fully working with some s...
# ...                                                 ...
# 6615                                                NaN
# 6616                                                NaN
# 6617                                                NaN
# 6618                                                NaN
# 6619                                                NaN
#
#                    Processor    Screen Size Manufacturer Color  Color  ...  \
# 0                  Quad Core          14 in                NaN   Gray  ...
# 1     Intel Core i7 8th Gen.          14 in                NaN  Black  ...
# 2        Intel Core i5-6300U          14 in                NaN  Black  ...
# 3            Intel Celeron N        11.6 in                NaN  Black  ...
# 4     Intel Core i5 6th Gen.  Minimum 12.5"                NaN    NaN  ...
# ...                      ...            ...                ...    ...  ...
# 6615                     NaN            NaN                NaN    NaN  ...
# 6616                     NaN            NaN                NaN  Negro  ...
# 6617                     NaN            NaN                NaN    NaN  ...
# 6618                     NaN            NaN                NaN  Black  ...
# 6619                     NaN            NaN                NaN    NaN  ...
#
#                          Processor Speed             Type  \
# 0                     Max up to 3.80 GHz  Notebook/Laptop
# 1     4.20 GHz (1.90 GHz Base Frequency)  Notebook/Laptop
# 2                               2.40 GHz  Notebook/Laptop
# 3                               2.40 GHz  Notebook/Laptop
# 4                       Minimum 1.40 GHz  Notebook/Laptop
# ...                                  ...              ...
# 6615                                 NaN              NaN
# 6616                                 NaN              NaN
# 6617                                 NaN              NaN
# 6618                                 NaN  Notebook/Laptop
# 6619                                 NaN              NaN
#
#              Release Year Maximum Resolution                Model  \
# 0                    2021        2160 x 1440           CoreBook X
# 1     Refurbished in 2023        1920 x 1080   Dell Latitude 7490
# 2                    2019        1920 x 1080  Dell Latitude E5470
# 3                     NaN         1366 x 768  HP Chromebook 11 G6
# 4                    2015         1366 x 768       Various Models
# ...                   ...                ...                  ...
# 6615                  NaN                NaN                  NaN
# 6616                  NaN                NaN                  NaN
# 6617                  NaN                NaN                  NaN
# 6618                  NaN                NaN                  NaN
# 6619                  NaN                NaN                  NaN
#
#                    OS                                           Features  \
# 0     Windows 11 Home  Backlit Keyboard,  Built-in Microphone,  Built...
# 1      Windows 11 Pro  Backlit Keyboard, Bluetooth, Built-in Micropho...
# 2      Windows 10 Pro  10/100 LAN Card, Backlit Keyboard, Bluetooth, ...
# 3           Chrome OS  Bluetooth, Built-in Microphone, Built-in Webca...
# 4          Windows 10  10/100 LAN Card, Built-in Microphone, Built-in...
# ...               ...                                                ...
# 6615              NaN                                                NaN
# 6616              NaN                                                NaN
# 6617              NaN                                                NaN
# 6618              NaN                                                NaN
# 6619              NaN                                                NaN
#
#      Hard Drive Capacity Country Region Of Manufacture  \
# 0             512 GB SSD                         China
# 1                   2 TB                           NaN
# 2                 500 GB                         China
# 3                  16 GB                           NaN
# 4                 NO HDD                           NaN
# ...                  ...                           ...
# 6615                 NaN                           NaN
# 6616                 NaN                           NaN
# 6617                 NaN                           NaN
# 6618                 NaN                           NaN
# 6619                 NaN                           NaN
#
#                  Storage Type
# 0     SSD (Solid State Drive)
# 1     SSD (Solid State Drive)
# 2     SSD (Solid State Drive)
# 3                        eMMC
# 4     SSD (Solid State Drive)
# ...                       ...
# 6615                      NaN
# 6616                      NaN
# 6617                      NaN
# 6618                      NaN
# 6619                      NaN
#
# [6620 rows x 23 columns]>

# %% [markdown]
# ##**Initial Data Challenges**
# As observed in the basic data exploration, we have many data challenges to be overcome. Including:
#
# * The Price (Target Variable) is not numeric and contains diverse formats, including ranges.
# * Missing Brand data (39% of records), which is a big factor for pricing.
# * Computer specs in different formats.
#
# Proposed approach for these issues:
# * Clean the data and engineer features that can be used when training our models. Such as numeric price, or ordinal categories for computer specs.
# * Iteratively engineer features we deem more important, train our models, and decide which features to use based on observed results.
#    * Ex: Should we remove the datapoints that have no brand or should we create an unknown brand category?
#    * Ex: Extract processor tier (i7 vs i5) vs parsing detailed processor specifications?

# %% [markdown]
# ###**Data Clean-UP: Price (Target Variable)**
# The initial analysis indicated two patterns:
# *   Single price("\$X,XXX.XX")
# *   Price range("\$X,XXX.XX to \$X,XXX.XX")
#    *   For the purposes of this project, we decided to use the price range average as the new price.
#
# We will cleanup these patterns and analyze the field again to check if more treatment is needed.

# %%
#The initial analysis of the analysis indicates two patterns:

#Function to clan the price column and transfort into a float.
def clean_price(price_str):
  price_str = price_str.strip()
  if ' to 'in price_str:
    prices = price_str.split(' to ')
    price1 = float(prices[0].replace('$','').replace(',',''))
    price2 = float(prices[1].replace('$','').replace(',',''))
    return round((price1+price2)/2,2)
  else:
    return round(float(price_str.replace('$','').replace(',','')),2)

#Aplly cleaning function
df['price_clean'] = df['Price'].apply(clean_price)

#Get the statistical summary of the clean price
print(f"Statistical Summary of new price:\n {df['price_clean'].describe()}")

#Random sample
print(f"\nRandom Sample of 5 rows:\n{df.sample(5, random_state=42)}")

#Taking a look at the row with the highest price
print (f"Row with highest price:\n{df.loc[df['price_clean'].idxmax()]}")

#It seems we don't need any more treatment in this field.
# Out:
# Statistical Summary of new price:
#  count    6620.000000
# mean      310.046627
# std       399.076572
# min         4.730000
# 25%        90.990000
# 50%       193.120000
# 75%       387.137500
# max      3901.000000
# Name: price_clean, dtype: float64
#
# Random Sample of 5 rows:
#      Brand     Price Rating  Ratings Count  \
# 96     NaN   $59.42     NaN            NaN
# 994    NaN  $130.02     NaN            NaN
# 1400   NaN   $70.60     NaN            NaN
# 865    NaN  $338.76     NaN            NaN
# 6095  Dell  $105.01     NaN            NaN
#
#                                               Condition  \
# 96    New: A brand-new, unused, unopened, undamaged ...
# 994   New: A brand-new, unused, unopened, undamaged ...
# 1400  New: A brand-new, unused, unopened, undamaged ...
# 865   Used: An item that has been used previously. T...
# 6095  UsedAn item that has been used previously. The...
#
#                                             Seller Note  \
# 96                                                  NaN
# 994                                                 NaN
# 1400                                                NaN
# 865                                                 NaN
# 6095  “Good used condition. Some minor scratches and...
#
#                    Processor Screen Size Manufacturer Color  Color  ...  \
# 96                       NaN         NaN                NaN    NaN  ...
# 994                      NaN         NaN                NaN    NaN  ...
# 1400                     NaN         NaN                NaN    NaN  ...
# 865                      NaN         NaN                NaN    NaN  ...
# 6095  Intel Core i5 6th Gen.       14 in                NaN  Black  ...
#
#                                  Type Release Year Maximum Resolution  \
# 96                                NaN          NaN                NaN
# 994                               NaN          NaN                NaN
# 1400                              NaN          NaN                NaN
# 865   Ordinateur portable/Pc portable          NaN                NaN
# 6095                  Notebook/Laptop          NaN        1920 x 1080
#
#           Model              OS                                   Features  \
# 96          NaN             NaN                                        NaN
# 994         NaN             NaN                                        NaN
# 1400        NaN             NaN                                        NaN
# 865         NaN             NaN                                        NaN
# 6095  Dell 5470  Windows 10 Pro  10/100 LAN Card,  Built-in Webcam,  Wi-Fi
#
#      Hard Drive Capacity Country Region Of Manufacture  \
# 96                   NaN                           NaN
# 994                  NaN                           NaN
# 1400                 NaN                           NaN
# 865                  NaN                           NaN
# 6095              256 GB                           NaN
#
#                  Storage Type price_clean
# 96                        NaN       59.42
# 994                       NaN      130.02
# 1400                      NaN       70.60
# 865                       NaN      338.76
# 6095  SSD (Solid State Drive)      105.01
#
# [5 rows x 24 columns]
# Row with highest price:
# Brand                                                                    Alienware
# Price                                                                   $3,901.00
# Rating                                                                         NaN
# Ratings Count                                                                  NaN
# Condition                        New: A brand-new, unused, unopened, undamaged ...
# Seller Note                                                                    NaN
# Processor                                                  Intel Core i9 13th Gen.
# Screen Size                                                                  18 in
# Manufacturer Color                                                             NaN
# Color                                                                        Black
# Ram Size                                                                     64 GB
# SSD Capacity                                                                  4 GB
# GPU                                                        NVIDIA GeForce RTX 4090
# Processor Speed                                                                NaN
# Type                                                               Notebook/Laptop
# Release Year                                                                  2023
# Maximum Resolution                                                             NaN
# Model                                                                 Alienware 18
# OS                                                                 Windows 11 Home
# Features                                                                       NaN
# Hard Drive Capacity                                                           4 TB
# Country Region Of Manufacture                                                  NaN
# Storage Type                                               SSD (Solid State Drive)
# price_clean                                                                 3901.0
# Name: 2733, dtype: object

# %% [markdown]
# ###**Data Clean-up: Brand**
# The initial analysis for brand (see below) showed us that this field needs much more cleaning than Price. Including:
# * A number of words and phrases that should be considered "unknown" (Ex. "Major Brand" and "?)".
# * Records with multiple unrelated brands
# * Part Numbers as Brand
# * Specific Models as Brand
# * Other entries as Brand (ex. "LCD Replacement")

# %%
# Check unique brand values
# Null values dropped to allow sorting
sorted_brands = sorted(df['Brand'].dropna().unique())

print(f"Numer of unique brands: {len(sorted_brands)}")
for brand in sorted_brands:
   print(brand)

print(f"\nUnique values separated by a slash:\n{df[df['Brand'].str.contains('/', na=False)]['Brand'].unique()}")
# Out:
# Numer of unique brands: 134
# ?
# ACER
# AIRBAR
# AMIAMO
# ASUS
# AU Optronics
# AUO
# AUUSDA
# Acer
# Acer / IOmega
# Alienware
# Apple
# Apple / LG
# Asem
# Asus
# Bormann
# C600
# CHUNGHWA
# CHUNGWA
# CHUWI
# CLAA116WA03A
# CLAA156WA11A
# CLAA156WA13A
# CLEVO
# Casio
# ChiMei
# ChiMei INNOLUX
# Chimei INNOLUX
# Chingwa
# Chunghwa
# Chuwi
# Compaq
# Craig
# DELL
# DELL/HP/LENOVO/Fujitsu/Toshiba
# Dell
# Dell 16gb
# Dell Inc.
# Dell Inspiron
# Dell Latitude
# Dell Latitude 7275
# Dell/HP/Lenovo/Stone
# Delta
# Delta / DELL
# Different
# Does not apply
# Durabook
# FEC
# Frontier
# Fuji
# Fujitsu
# Fujitsu PC Corp.
# Fujitsu Siemens
# Fusion5
# GERICOM
# GETAC
# GIGABYTE
# GPD
# Gateway
# Geo
# Getac
# GoldBook
# Google
# HP
# HP DELL LENOVO SELECT FROM ABOVE
# HW13WX001
# HannStar
# HannnStar
# HiDes
# Huawei
# Hyundai
# IBM
# INNOLUX
# IVO
# InnoLux
# Insignia
# Intel
# JVC
# Jumper
# KODAK
# Kano
# Kodak
# LCD Replacement
# LENOVO
# LG
# Lenova
# Lenovo
# Lenovo T440
# Lenovo T530
# LiteON
# MEDION
# MSI
# Major Brand
# Media Wave
# Metabox
# Microsoft
# Mixt
# Motion Computing
# Mouse Computer
# Not Applicable
# Olidata
# Olpc
# Olympus
# Orbitkey
# PANASONIC
# Packard Bell
# Packard bell
# Panasonic
# ProBook
# Razer
# SCSI
# SGIN
# Samsung
# See Title/Description
# Shed Number 2
# Simpletek
# Sony
# Sony VAIO
# Top Performance
# Toshiba
# Unbranded
# Unbranded/Generic
# Universal
# Uniwill
# VAIO
# VECTOR
# Vulcan Electronics
# XPLORE
# Zebra
# Zzetze
# dell
# nevada
# www.TAG1000Diver.com
# xnote
#
# Records with unrelated brands separated by a slash:
# ['See Title/Description' 'DELL/HP/LENOVO/Fujitsu/Toshiba'
#  'Unbranded/Generic' 'Apple / LG' 'Delta / DELL' 'Dell/HP/Lenovo/Stone'
#  'Acer / IOmega']

# %% [markdown]
# **Proposed Clean-up Logic**
#
#
# 1. Null Brands are considered "unknown"
# 2. The case for the Brand will be standardized before comparison.
# 3. Brands in the bad brands list are considered "unknown"
# 4. Brands with forward slash ("/") are considered unknown.
#   * The number of affected records in this dataset is small.
#   * This rule is justified in a real-world scenario as the "/" indicates uncertainty about the Brand or a mixed item. Still, we would revisit this rule with a different datase.
#   * We are applying this generic rule after the more specific bad brands match.
# 5. We will match the brands with a list of "known brands".
#    * For this project, we sourced the list from wikipedia (https://en.wikipedia.org/wiki/List_of_laptop_brands_and_manufacturers)
# 6. Finally, if there are no matches, we will consider the brand as "unknown"
